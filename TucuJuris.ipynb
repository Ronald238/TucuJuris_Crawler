# %%
import requests
from bs4 import BeautifulSoup

# %%
s = requests.session()
Url = 'https://tucujuris.tjap.jus.br/tucujuris/pages/consultar-processo/consultar-processo.html'
login = s.request('Get',Url)
capc = 'https://tucujuris.tjap.jus.br/api/publico/buscar-passe-captcha'

headers = {'authority': 'tucujuris.tjap.jus.br',
'accept': 'application/json',
    'accept-language': 'pt-BR,pt;q=0.9',
    # 'cookie': '_ga=GA1.3.47228615.1674136806; _gid=GA1.3.1354223988.1674136806; _gat=1',
    'referer': 'https://tucujuris.tjap.jus.br/tucujuris/pages/consultar-processo/consultar-processo.html',
    'sec-ch-ua': '"Not_A Brand";v="99", "Google Chrome";v="109", "Chromium";v="109"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'tucujuris-front-url': 'https://tucujuris.tjap.jus.br/tucujuris/pages/consultar-processo/consultar-processo.html',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36'}

for i in range(100):
    result_cap = s.request('Get',capc,headers=headers)
    if result_cap.json()['dados'] != None:
        break

result_cap.json()['dados'] == None
# Out:
# False

# %%
a = result_cap
data = result_cap.json()
data.get('dados')
# Out:
# '329c6a287560e640576d59f4b'

# %%
import requests

headers = {
    'authority': 'tucujuris.tjap.jus.br',
    'accept': 'application/json',
    'accept-language': 'pt-BR,pt;q=0.9',
    'referer': 'https://tucujuris.tjap.jus.br/tucujuris/pages/consultar-processo/consultar-processo.html',
    'sec-ch-ua': '"Not_A Brand";v="99", "Google Chrome";v="109", "Chromium";v="109"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'tucujuris-front-url': 'https://tucujuris.tjap.jus.br/tucujuris/pages/consultar-processo/consultar-processo.html',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36',
}

params = {
    'id': '',
    'numero_unico': '',
    'nome_parte': 'joao rosa',
    'documento_parte': '',
    'nome_advogado': '',
    'oab_advogado': '',
    'numero_carta_precatoria': '',
    'situacao_processo': '',
    'captcha': data.get('dados'),
}

response = s.request('GET',
    'https://tucujuris.tjap.jus.br/api/publico/buscar-autos-consulta-publica',
    params=params,
    headers=headers,
)

# %%
response.json()
response_json = response.json()
response_json.keys()
# Out:
# dict_keys(['ambiente', 'status', 'dados'])

# %%
response.json()
autos_processos = response_json['dados']['autos'][0].get('chave_consumo')
print(autos_processos)

# %%
response.json()
autos_processos
# Out:
# ''

# %%
import requests

cookies = {
    '_ga': 'GA1.3.343072669.1678900825',
    '_gid': 'GA1.3.159596744.1678900825',
}

headers = {
    'authority': 'tucujuris.tjap.jus.br',
    'accept': 'application/json',
    'accept-language': 'pt-BR,pt;q=0.9',
    # 'cookie': '_ga=GA1.3.343072669.1678900825; _gid=GA1.3.159596744.1678900825',
    'referer': 'https://tucujuris.tjap.jus.br/tucujuris/pages/consultar-processo/consultar-processo.html',
    'sec-ch-ua': '"Google Chrome";v="111", "Not(A:Brand";v="8", "Chromium";v="111"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'tucujuris-front-url': 'https://tucujuris.tjap.jus.br/tucujuris/pages/consultar-processo/consultar-processo.html',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36',
}

params = {
    'autos_id': '2345022',
    'chave_consumo': '',
}

response = requests.get(
    'https://tucujuris.tjap.jus.br/api/publico/buscar-detalhes-autos-consulta-publica',
    params=params,
    cookies=cookies,
    headers=headers,
)


response.json()['dados']['movimentos']
# Out:
# [{'qtd_anexo': 0,
#   'conteudo': None,
#   'id_pa': 71649089,
#   'descricao_pa': 'Expedição de Certidão.',
#   'complemento_pa': 'Ademais, determino que seja promovida, com urgência, a realização de bloqueio judicial do valor da multa atribuída, via sisbajud.',
#   'dt_andamento_pa': '2023-03-13 08:07:13.317309',
#   'dt_prazo_pa': '2023-03-27',
#   'nome_tabela_pa': 'processosrotinas',
#   'publicacao_internet_pa': None,
#   'id_conteudo': 25368010,
#   'ordem': 18,
#   'cancelado': False},
#  {'qtd_anexo': 1,
#   'conteudo': None,
#   'id_pa': 71632960,
#   'descricao_pa': 'Expedição de Mandado.',
#   'complemento_pa': 'MANDADO DE INTIMAÇÃO - GERAL para - UNIMED MACAPÁ COOPERATIVA DE TRABALHO MÉDICO LTDA - emitido(a) em 10/03/2023',
#   'dt_andamento_pa': '2023-03-10 13:23:27.024169',
#   'dt_prazo_pa': '2023-04-10',
#   'nome_tabela_pa': 'documentosemitidos',
#   'publicacao_internet_pa': None,
#   'id_conteudo': 4325987,
#   'ordem': 17,
#   'cancelado': False},
# ...

# %%
def consulta_Processo(params: dict, headers: dict):
        for i in range(100):
            try:
                response_processo_json = requests.request('GET',
                        'https://tucujuris.tjap.jus.br/api/publico/buscar-detalhes-autos-consulta-publica',
                        params=params,
                        headers=headers,)

                movimentos = response_processo_json.json()['dados']['movimentos']
                return response_processo_json.json()
            except:
                continue
        


dados_total = list()
cont = 0

autos_processos = response_json['dados']['autos']
for auto in autos_processos:
    cont += 1 
    id = auto.get('id')
    params = {
    'autos_id': id,
    'chave_consumo': 'Batata',
}
    
    headers = {
        'authority': 'tucujuris.tjap.jus.br',
        'accept': 'application/json',
        'accept-language': 'pt-BR,pt;q=0.9',
        # 'cookie': '_ga=GA1.3.343072669.1678900825; _gid=GA1.3.159596744.1678900825',
        'referer': 'https://tucujuris.tjap.jus.br/tucujuris/pages/consultar-processo/consultar-processo.html',
        'sec-ch-ua': '"Google Chrome";v="111", "Not(A:Brand";v="8", "Chromium";v="111"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
        'sec-fetch-dest': 'empty',
        'sec-fetch-mode': 'cors',
        'sec-fetch-site': 'same-origin',
        'tucujuris-front-url': 'https://tucujuris.tjap.jus.br/tucujuris/pages/consultar-processo/consultar-processo.html',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36',
    }
    
    response_processo_json = consulta_Processo(params=params, headers=headers)
    movimentos = response_processo_json['dados']['movimentos']
    movimentacao = list()
    for movimento in movimentos:
        movimentacao.append({
            'titulo': movimento.get('descricao_pa'),
            'andamento': movimento.get('complemento_pa'),
            'data': movimento.get('dt_prazo_pa'),
            })

    response_processo_json
    json1 = response_processo_json

    infos = json1['dados']['cabecalho']
    partes_json = json1['dados']['capa']
    partes = list()


    for parte in partes_json:
        if parte['tipoparte'] == 'PARTE AUTORA':
            partes.append({
                'nome': parte.get('nomeparte'),
                'tipo': 'autor'
            })
        else:
            partes.append({
                'nome': parte.get('nomeparte'),
                'tipo': 'reu'
            })

    for parte in partes_json:
        if parte['tipoparte'] == 'PARTE AUTORA':
            partes.append({
                'nome advogado': parte.get('nome_adv'),
                'tipo': 'autor'
            })
        else:
            partes.append({
                'nome advogado': parte.get('nome_adv'),
                'tipo': 'reu'
            })

    dados = dict()
    dados['numero_processo'] = infos.get('numero_cnj', '')
    dados['classe_processo'] = infos.get('classe', '')
    dados['area_processo'] = infos.get('comarca', '')
    dados['assunto_processo'] = infos.get('rito', '')
    dados['valor_processo'] = infos.get('valor_causa', '')
    dados['vara_processo'] = infos.get('lotacao', '')
    dados['tribunal'] = 'Tucujuris'
    dados['partes'] = partes
    dados['movimentacoes'] = movimentacao
    dados_total.append(dados)

# %%
def consulta_Processo(params: dict, headers: dict):
        for i in range(100):
            try:
                response_processo_json = requests.request('GET',
                        'https://tucujuris.tjap.jus.br/api/publico/buscar-detalhes-autos-consulta-publica',
                        params=params,
                        headers=headers,)

                movimentos = response_processo_json.json()['dados']['movimentos']
                return movimentos
            except:
                continue

# %%
params
# Out:
# {'autos_id': 1913432, 'chave_consumo': 'Batata'}

# %%
len(dados_total)
response_processo_json.content
dados
# Out:
# {'numero_processo': '0005216-98.2016.8.03.0008',
#  'classe_processo': 'PROCEDIMENTO DO JUIZADO ESPECIAL CÍVEL',
#  'area_processo': 'LARANJAL DO JARI',
#  'assunto_processo': 'PROCEDIMENTO SUMARÍSSIMO - EXECUÇÃO/CUMPRIMENTO DE SENTENÇA',
#  'valor_processo': 6251,
#  'vara_processo': 'VARA DO JUIZADO ESPECIAL CÍVEL, CRIMINAL E FAZENDA PÚBLICA',
#  'tribunal': 'Tucujuris',
#  'partes': [{'nome': 'JOÃO NILSON VIEIRA DO ROSÁRIO', 'tipo': 'autor'},
#   {'nome': 'INSTITUTO DO MEIO AMBIENTE E DE ORDENAMENTO TERRITORIAL DO ESTADO DO AMAPA',
#    'tipo': 'reu'},
#   {'nome advogado': 'PAULIANE SOUSA CAVALCANTE', 'tipo': 'autor'},
#   {'nome advogado': 'PROCURADORIA GERAL DO ESTADO DO AMAPA', 'tipo': 'reu'}],
#  'movimentacoes': [{'titulo': 'Arquivado Definitivamente - Nº de Volumes: 1',
#    'andamento': 'Promovo o arquivamento dos presentes autos, em atendimento à determinação deste Juízo/Tribunal.',
#    'data': '2019-04-01'},
# ...

# %%
params = {
    'autos_id': id,
    'chave_consumo': '',
}

response_processo_json = s.request('GET',
    'https://tucujuris.tjap.jus.br/api/publico/buscar-detalhes-autos-consulta-publica',
    params=params,
    headers=headers,
)
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File c:\Users\ronal\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# ...

# %%
movimentos = response_processo_json.json()['dados']['movimentos']
movimentacao = list()
for movimento in movimentos:
    movimentacao.append({
        'titulo': movimento.get('descricao_pa'),
        'andamento': movimento.get('complemento_pa'),
        'data': movimento.get('dt_prazo_pa'),
        })

movimentacao
# Out:
# [{'titulo': 'Expedição de Certidão.',
#   'andamento': 'Certifico que o processo ficará suspenso até a resolução do Incidente de Resolução de Demandas Repetitivas, tombado sob o nº0003649-80.2021.8.03.0000.',
#   'data': '2023-09-07'},
#  {'titulo': 'Ocorrência Processual Certificada',
#   'andamento': 'Certifico e dou fé que o processo ficará SUSPENSO, conforme determinação do R. Juízo- evento de ordem n°04.',
#   'data': '2022-11-22'},
#  {'titulo': 'Processo Suspenso por depender do julgamento de outra causa, de outro juízo ou declaração incidente',
#   'andamento': 'Em Atos do Juiz. A pretensão indenizatória, objeto desta ação, possui como causa de pedir o “Apagão” ocorrido no Estado do Amapá em novembro/2020, fruto de um incêndio sofrido em um dos transformadores da subestação de Macapá/AP.É fato público e notório q (...)',
#   'data': '2022-02-25'},
#  {'titulo': 'Conclusos para despacho.',
#   'andamento': 'CONCLUSO AO MAGISTRADO(A) LUCIANA BARROS DE CAMARGO',
# ...

# %%
response_processo_json.content
json1 = response_processo_json.json()

# %%
infos = json1['dados']['cabecalho']
partes_json = json1['dados']['capa']
print(partes_json)
partes = list()


for parte in partes_json:
    if parte['tipoparte'] == 'PARTE AUTORA':
        partes.append({
            'nome': parte.get('nomeparte'),
            'tipo': 'autor'
        })
    else:
        partes.append({
            'nome': parte.get('nomeparte'),
            'tipo': 'reu'
        })

for parte in partes_json:
    if parte['tipoparte'] == 'PARTE AUTORA':
        partes.append({
            'nome advogado': parte.get('nome_adv'),
            'tipo': 'autor'
        })
    else:
        partes.append({
            'nome advogado': parte.get('nome_adv'),
            'tipo': 'reu'
        })

partes
# Out:
# [{'idproc': 2019093, 'tipoparte': 'PARTE AUTORA', 'nomeparte': 'JOÃO TAVARES DO ROSARIO', 'nome_adv': 'PAULO VICTOR ROSÁRIO DOS SANTOS', 'titulo_documentos': 'Advogado(a): ', 'idpessoa': 3503949, 'principal': True}, {'idproc': 2019093, 'tipoparte': 'PARTE RÉ', 'nomeparte': 'LINHAS DE MACAPÁ TRANSMISSORA DE ENERGIA S.A.', 'nome_adv': None, 'titulo_documentos': None, 'idpessoa': 3822854, 'principal': True}]
# [{'nome': 'JOÃO TAVARES DO ROSARIO', 'tipo': 'autor'},
#  {'nome': 'LINHAS DE MACAPÁ TRANSMISSORA DE ENERGIA S.A.', 'tipo': 'reu'},
#  {'nome advogado': 'PAULO VICTOR ROSÁRIO DOS SANTOS', 'tipo': 'autor'},
#  {'nome advogado': None, 'tipo': 'reu'}]

# %%
dados = dict()
dados['numero_processo'] = infos.get('numero_cnj', '')
dados['classe_processo'] = infos.get('classe', '')
dados['area_processo'] = infos.get('comarca', '')
dados['assunto_processo'] = infos.get('rito', '')
dados['valor_processo'] = infos.get('valor_causa', '')
dados['vara_processo'] = infos.get('lotacao', '')
dados['tribunal'] = 'Tucujuris'
dados['partes'] = partes
dados['movimentacoes'] = movimentacao

# %%
dados
# Out:
# {'numero_processo': '0007111-08.2022.8.03.0001',
#  'classe_processo': 'PROCEDIMENTO DO JUIZADO ESPECIAL CÍVEL',
#  'area_processo': 'MACAPÁ',
#  'assunto_processo': 'PROCEDIMENTO SUMARÍSSIMO - CONHECIMENTO',
#  'valor_processo': 10000,
#  'vara_processo': '3ª VARA DO JUIZADO ESPECIAL CÍVEL - CENTRO',
#  'tribunal': 'Tucujuris',
#  'partes': [{'nome': 'JOÃO TAVARES DO ROSARIO', 'tipo': 'autor'},
#   {'nome': 'LINHAS DE MACAPÁ TRANSMISSORA DE ENERGIA S.A.', 'tipo': 'reu'},
#   {'nome advogado': 'PAULO VICTOR ROSÁRIO DOS SANTOS', 'tipo': 'autor'},
#   {'nome advogado': None, 'tipo': 'reu'}],
#  'movimentacoes': [{'titulo': 'Expedição de Certidão.',
#    'andamento': 'Certifico que o processo ficará suspenso até a resolução do Incidente de Resolução de Demandas Repetitivas, tombado sob o nº0003649-80.2021.8.03.0000.',
#    'data': '2023-09-07'},
#   {'titulo': 'Ocorrência Processual Certificada',
# ...
